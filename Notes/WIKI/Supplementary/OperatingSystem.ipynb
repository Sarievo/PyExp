# %% [markdown]
# ### Navigating the System
#
# **Supplemental Reading for Windows CLI & Unix Bash**
#
# [Official PowerShell documentation](https://docs.microsoft.com/powershell/), [PowerShell 101 guide](https://docs.microsoft.com/powershell/scripting/learn/ps101/00-introduction).
#
# Older Windows "[Command Prompt](https://docs.microsoft.com/en-us/windows-server/administration/windows-commands/windows-commands)" CLI (cmd.exe), [Bash Manual](https://www.gnu.org/software/bash/manual/bash.html)
#
# **Supplemental Reading for ['Size' vs 'Size of Disk'](https://technet.microsoft.com/en-us/library/hh148159.aspx) in Windows**
#
# **Supplemental Reading for [Notepad++](https://notepad-plus-plus.org/)**
#
# **Supplemental Reading for GNU Documentation**
#
# for [nano-editor](https://www.nano-editor.org/), for [Vim](https://vim.sourceforge.io/docs.php) and [Emacs](https://www.gnu.org/software/emacs/tour/).
#
# **Supplemental Reading for Windows PowerShell**
#
# [training-courses/getting-started](https://mva.microsoft.com/en-us/training-courses/getting-started-with-microsoft-powershell-8276), [learning-powershell/README.md](https://github.com/PowerShell/PowerShell/blob/master/docs/learning-powershell/README.md)
#
# ### Users and Permissions
#
# **Supplemental Reading for [Windows Passwords](https://msdn.microsoft.com/en-us/library/cc875839.aspx)**
#
# **Supplemental Readings for Mobile Users and Accounts**
#
# Adding accounts [to iOS](https://support.apple.com/HT201320), and [to Android](https://support.google.com/nexus/answer/7664951)
#
# [Multiple user accounts on Android](https://support.google.com/nexus/answer/2865483)
#
# **Supplemental Reading for [Windows ACL](https://msdn.microsoft.com/en-us/library/windows/desktop/aa374872(v=vs.85).aspx)**
#
# **Supplemental Reading for [Special Permissions in Windows](https://technet.microsoft.com/en-us/library/cc732880(v=ws.11).aspx)**
#
# ### Package and Software Management
#
# *Software Distribution*
#
# **Supplemental Reading for Windows Software Packages**
#
# [portable executable](https://en.wikipedia.org/wiki/Portable_Executable), [Installation Package](https://msdn.microsoft.com/en-us/library/windows/desktop/aa369294(v=vs.85).aspx), [Windows Store](https://en.wikipedia.org/wiki/Windows_Store), and [App packager (MakeAppx.exe)](https://msdn.microsoft.com/en-us/library/windows/desktop/hh446767(v=vs.85).aspx). [Microsoft Self-Extractor](https://support.microsoft.com/en-us/help/912203/description-of-the-command-line-switches-that-are-supported-by-a-softw).
#
# **Supplemental Reading for Mobile App Packages**
#
# [Distributing custom apps for business](https://developer.apple.com/business/custom-apps/)
#
# [Get started with custom app publishing](https://developers.google.com/android/work/play/custom-app-api/get-started)
#
# [How to check the storage on iOS](https://support.apple.com/HT201656), and [in Android](https://support.google.com/android/answer/7431795)
#
# [App updates in iOS](https://support.apple.com/HT204266), and [in Android](https://support.google.com/googleplay/answer/113412)
#
# **Supplemental Reading for [7-Zip](http://www.7-zip.org/download.html) and [PowerShell Zips](https://docs.microsoft.com/en-us/powershell/module/microsoft.powershell.archive/compress-archive?view=powershell-5.0)**
#
# **Supplemental Reading for the [Linux Tar Command](http://www.linfo.org/tar.html)**
#
# **Supplemental reading for Windows Package Dependencies**
#
# [Dynamic- link library](https://en.wikipedia.org/wiki/Dynamic-link_library), [DLL Hell](https://en.wikipedia.org/wiki/DLL_Hell), [Side- by- side Assemblies](https://msdn.microsoft.com/en-us/library/aa376307.aspx).
#
# [PowerShell Gallery](http://www.powershellgallery.com/).
#
# **Supplemental Reading for** Linux Package Dependencies **(**dpkg)
#
# *Package Managers*
#
# **Supplemental Reading for Windows Package Managers**
#
# [NuGet](https://en.wikipedia.org/wiki/NuGet) and [chocolatey](https://chocolatey.org/packages).
#
# **Supplemental Reading for [Linux PPAs](https://help.launchpad.net/Packaging/PPA)** (Personal Package Archives)
#
# **Supplemental Reading on [GIMP](https://www.gimp.org/downloads/)**
#
# *What's happening in the background?*
#
# **Supplemental Reading for Windows Installers and Process Monitors**
#
# [Process Monitor](https://docs.microsoft.com/en-us/sysinternals/downloads/procmon), [Windows Installer Examples](https://msdn.microsoft.com/en-us/library/windows/desktop/aa372837(v=vs.85).aspx), and [Orca.exe](https://msdn.microsoft.com/en-us/library/windows/desktop/aa370557(v=vs.85).aspx).
#
# *Device Software Management*
#
# **Supplemental Reading Windows Devices and Drivers**
#
# [introduction-to-plug-and-play](https://docs.microsoft.com/en-us/windows-hardware/drivers/kernel/introduction-to-plug-and-play)
#
# [drivers/install/step-1--the-new-device-is-identified](https://docs.microsoft.com/en-us/windows-hardware/drivers/install/step-1--the-new-device-is-identified)
#
# [drivers/install/hardware-ids](https://docs.microsoft.com/en-us/windows-hardware/drivers/install/hardware-ids)
#
# [drivers/install/step-2--a-driver-for-the-device-is-selected](https://docs.microsoft.com/en-us/windows-hardware/drivers/install/step-2--a-driver-for-the-device-is-selected)
#
# **Supplemental reading for Linux Devices and Drivers**
#
# [Device_file](https://en.wikipedia.org/wiki/Device_file) and for [Udev](https://en.wikipedia.org/wiki/Udev)
#
# **Supplemental Reading for Windows Update**
#
# [Windows_Update](https://en.wikipedia.org/wiki/Windows_Update), [2010/06/windows-update-explained](http://configmgr2012.blogspot.com/2010/06/windows-update-explained.html#_Toc210097879)
#
# [further-simplifying-servicing-model-for-windows-7-and-windows-8](https://blogs.technet.microsoft.com/windowsitpro/2016/08/15/further-simplifying-servicing-model-for-windows-7-and-windows-8-1/)
#
# **Supplemental Reading for Linux Update**
#
# [Linux_kernel](https://en.wikipedia.org/wiki/Linux_kernel), [learn/linux-101-updating-your-system](https://www.linux.com/learn/linux-101-updating-your-system)
#
# [faq/how-do-i-update-ubuntu-linux-softwares/](https://www.cyberciti.biz/faq/how-do-i-update-ubuntu-linux-softwares/)
#
# ### Process Management
#
# **Supplemental Reading for [FAT32 File System](https://support.microsoft.com/en-us/help/154997/description-of-the-fat32-file-system)**
#
# **Supplemental Reading for Disk Partitioning & Formatting in Windows**
#
# [Setting the allocation unit size when formatting a disk](https://support.microsoft.com/en-us/help/140365/default-cluster-size-for-ntfs--fat--and-exfat)
#
# [DiskPart command-line options](https://technet.microsoft.com/en-us/library/cc766465(v=ws.10).aspx).
#
# **Supplemental reading [Mounting & Unmounting a Filesystem in Linux](https://en.wikipedia.org/wiki/Fstab)**
#
# **Supplemental Reading for Windows Paging**
#
# [Paging#Windows_NT](https://en.wikipedia.org/wiki/Paging#Windows_NT)
#
# [how-to-determine-the-appropriate-page-file-size-for-Windows 64](https://support.microsoft.com/en-us/help/2860880/how-to-determine-the-appropriate-page-file-size-for-64-bit-versions-of)
#
# **Supplemental Reading for [Linux Swap](https://access.redhat.com/documentation/en-us/red_hat_enterprise_linux/7/html/storage_administration_guide/ch-swapspace)**
#
# **Supplemental Reading on NTFS File System**
#
# [Master File Table](https://msdn.microsoft.com/en-us/library/windows/desktop/aa365230(v=vs.85).aspx), [Creating Symbolic Links](https://msdn.microsoft.com/en-us/library/windows/desktop/aa363878(v=vs.85).aspx)
#
# [Hard Links and Junctions](https://msdn.microsoft.com/en-us/library/windows/desktop/aa365006(v=vs.85).aspx).
#
# **Supplemental Reading for Windows Disk Usage**
#
# [Disk Usage](https://docs.microsoft.com/en-us/sysinternals/downloads/du), [How to start Disk Cleanup by using the command line](https://support.microsoft.com/en-us/help/181701/how-to-start-disk-cleanup-by-using-the-command-line).
#
# **Supplemental Reading for [Linux Disk Usage](https://www.howtogeek.com/115229/htg-explains-why-linux-doesnt-need-defragmenting/)**
#
# **Supplemental Reading for [Linux Filesystem Repair](https://en.wikipedia.org/wiki/Fsck)** (fsck)
#
# ### Operating Systems in Practice
#
# **Supplemental Reading for [Process Creation & Termination in Windows](https://docs.microsoft.com/en-us/windows-server/administration/windows-commands/taskkill)**
#
# **Supplemental Reading for [Reading Process Information in Windows](https://docs.microsoft.com/en-us/powershell/module/microsoft.powershell.management/get-process?view=powershell-5.1)**
#
# **Supplemental Reading for [Reading Process Information in Linux](https://man7.org/linux/man-pages/man1/ps.1.html)**
#
# **Supplemental Reading for [Windows Signal](https://docs.microsoft.com/en-us/cpp/c-runtime-library/reference/signal?view=msvc-160)**
#
# **Supplemental Reading for [Managing Processes in Window](https://docs.microsoft.com/en-us/sysinternals/downloads/process-explorer)**
#
# **Supplemental Readings for Mobile App Management**
#
# **[Switching apps in iOS](https://support.apple.com/HT202070)**
#
# **[How to force an app to close in iOS](https://support.apple.com/HT201330)**
#
# **[Find, open & close apps in Android](https://support.google.com/pixelphone/answer/2781964)**
#
# **[Android processes and application Lifecycle](https://developer.android.com/guide/components/activities/process-lifecycle)**
#
# **[iOS - Battery and performance for iOS](https://support.apple.com/HT208387)**
#
# **[Fix battery drain problems for Android](https://support.google.com/pixelphone/answer/6090599)**
#
# **Supplemental Reading [Resource Monitoring in Windows](https://docs.microsoft.com/en-us/powershell/module/microsoft.powershell.management/get-process?view=powershell-5.1#outputs)**
#
# **Supplemental reading for [Resource Monitoring in Linux](https://en.wikipedia.org/wiki/Load_(computing))**
