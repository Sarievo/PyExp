# %% [markdown]
# ### Network and Infrastructure Services
#
# **Supplemental Reading for IT Infrastructure Services**
#
# [IaaS](https://www.techrepublic.com/blog/the-enterprise-cloud/side-by-side-comparisons-of-iaas-service-providers/), [NaaS](https://en.wikipedia.org/wiki/Network_as_a_service), [SaaS](http://www.businessinsider.com/the-most-popular-cloud-apps-used-at-work-2015-8), and [PaaS Providers](https://www.techradar.com/best/best-paas-providers).
#
# [DaaS] [Amazon](https://aws.amazon.com/cloud-directory/), [Jumpcloud](https://jumpcloud.com/daas-product/index) and the [Azure Active Directory](https://azure.microsoft.com/en-us/services/active-directory/).
#
# **Supplemental Reading for [Server Operating Systems](https://www.pcworld.idg.com.au/article/151491/server_operating_systems/)**
#
# **Supplemental Reading for Remote Access and SSH**
#
# [OpenSSH](https://en.wikipedia.org/wiki/OpenSSH).
#
# **Windows remote access tools**: check out: [Remote Desktop Clients](https://docs.microsoft.com/en-us/windows-server/remote/remote-desktop-services/clients/remote-desktop-clients), [Windows Remote Management](https://msdn.microsoft.com/en-us/library/aa384291(v=vs.85).aspx) and [PuTTY](https://en.wikipedia.org/wiki/PuTTY).
#
# **Supplemental Reading for FTP Clients**
#
# [PXE Boot](https://en.wikipedia.org/wiki/Preboot_Execution_Environment), [FTP Clients](https://en.wikipedia.org/wiki/Comparison_of_FTP_client_software).
#
# **Supplemental Reading for DNS and DHCP**
#
# [top-dns-servers](https://blog.dnsimple.com/2015/02/top-dns-servers/) (2015), [Comparison_of_DHCP_server_software](https://en.wikipedia.org/wiki/Comparison_of_DHCP_server_software)
#
# ### Software and Platform Services
#
# **Supplemental Reading for Email Services**
#
# [Setup email server](https://www.digitalocean.com/community/tutorials/why-you-may-not-want-to-run-your-own-mail-server), [Email protocols](https://blog.servermania.com/what-protocols-send-receive-email-with-the-mail-server/).
#
# **Supplemental Reading for [File Services](https://www.cloudwards.net/comparison/)**
#
# **Supplemental Reading for Network File Storage**
#
# [SMB](https://technet.microsoft.com/en-us/library/hh831795(v=ws.11).aspx), [NFS server software](http://www.linuxfromscratch.org/blfs/view/cvs/basicnet/nfs-utils.html).
#
# **Supplemental Reading for Mobile Synchronization**
#
# **[Android](https://support.google.com/android/answer/2819582?hl=en)** and **[iOS](https://support.apple.com/HT203977#icloud).**
#
# **[Supplemental Reading for Print Services](https://www.coursera.org/learn/system-administration-it-infrastructure-services/supplement/Ne1xo/supplemental-reading-for-print-services)**
#
# **Supplemental Reading for Web Servers (Revisited)**
#
# [nginx, Apache HTTP and Microsoft IIS](https://stackshare.io/stackups/apache-httpd-vs-microsoft-iis-vs-nginx)
#
# **Supplemental Reading for Database Admin Jobs**
#
# Database [Admin Jobs](https://www.bls.gov/ooh/computer-and-information-technology/database-administrators.htm), and [Database types](https://www.digitalocean.com/community/tutorials/sqlite-vs-mysql-vs-postgresql-a-comparison-of-relational-database-management-systems).
#
# **Supplemental Reading for Troubleshooting with Developer Tools**
#
# [Chrome Developer Tools](https://developer.chrome.com/devtools) and [a list of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
#
# Reading for **Autoscaling** & **Load Balancing** → **Monitoring** & **Alerting**
#
# - [https://azure.microsoft.com/en-us/overview/what-is-cloud-computing/](https://azure.microsoft.com/en-us/overview/what-is-cloud-computing/)
# - [https://aws.amazon.com/getting-started/](https://aws.amazon.com/getting-started/)
# - [https://cloud.google.com/docs/overview/](https://cloud.google.com/docs/overview/)
#
# **Supplemental Reading for Centralized Management**
#
# [Role-based access control](https://en.wikipedia.org/wiki/Role-based_access_control), [Chef](https://www.chef.io/chef/), [Puppet](https://puppet.com/)
#
# [an Introduction to System Center Configuration Manager](https://docs.microsoft.com/en-us/sccm/core/understand/introduction).
#
# **Supplemental Reading for [LDAP format](https://en.wikipedia.org/wiki/LDAP_Data_Interchange_Format)**
#
# **Supplemental Reading for [Kerberos](https://technet.microsoft.com/en-us/library/cc780469(v=ws.10).aspx)**
#
# **Supplemental Reading for [Active Directory](https://technet.microsoft.com/en-us/library/cc961936.aspx)**
#
# **Supplemental Reading for Mobile Device Management (MDM)**
#
# - **iOS - [MDM Settings Payload list](https://support.apple.com/guide/mdm/payload-list-mdm5370d089/web)**
# - **Android - [Apply settings for Android mobile devices](https://support.google.com/a/answer/6328708#apply)**
# - **iOS - [Intro to Profile Manager](https://support.apple.com/guide/server/intro-to-profile-manager-apd0e2214c6/mac), [MDM Settings Payload list](https://support.apple.com/guide/mdm/payload-list-mdm5370d089/web)**
# - **Android - [Get started with Google Mobile Management](https://support.google.com/a/answer/7396025), [Apply settings for Android mobile devices](https://support.google.com/a/answer/6328708#apply)**
#
# **Supplemental Reading for OpenLDAP**
#
# [https://www.digitalocean.com/community/tutorials/how-to-install-and-configure-openldap-and-phpldapadmin-on-ubuntu-16-04](https://www.digitalocean.com/community/tutorials/how-to-install-and-configure-openldap-and-phpldapadmin-on-ubuntu-16-04)
#
# also [OpenLDAP.org](https://www.openldap.org/doc/admin24/slapdconf2.html)
#
# **Supplemental Reading for Managing OpenLDAP**
#
# [Data interchange format](https://en.wikipedia.org/wiki/LDAP_Data_Interchange_Format)
#
# [Use LDIF files to make changes to an OpenLDAP system](https://www.digitalocean.com/community/tutorials/how-to-use-ldif-files-to-make-changes-to-an-openldap-system)
#
# **Supplemental Reading for Group Security Principles**
#
# **[Group Scope](https://technet.microsoft.com/en-us/library/cc755692(v=ws.10).aspx)** and [**Security Principles**](https://technet.microsoft.com/en-us/library/cc780957%28v=ws.10%29.aspx?f=255&MSPPError=-2147217396)
#
# **Supplemental Reading for [EFS Features](https://technet.microsoft.com/en-us/library/cc962100.aspx)**
#
# **Supplemental Reading for DFL & FFL**
#
# [Forest and Domain Functional Levels](https://docs.microsoft.com/en-us/windows-server/identity/ad-ds/active-directory-functional-levels)
#
# **Supplemental Reading for Group Policy Troubleshooting**
#
# More information on how you can manually force a domain computer to resync by using the w32tm /resync command [found here](https://docs.microsoft.com/en-us/windows-server/identity/ad-ds/get-started/windows-time-service/how-the-windows-time-service-works) and [here](https://docs.microsoft.com/en-us/previous-versions/windows/it-pro/windows-xp/bb491016(v=technet.10)).
#
# More information on how to troubleshoot Active Directory replication can be [found here](https://msdn.microsoft.com/en-us/library/bb727055.aspx).
#
# More information on controlling the scope of a Group Policy Object can be [found here](https://docs.microsoft.com/en-us/previous-versions/windows/it-pro/windows-server-2008-R2-and-2008/cc772166(v=ws.11)) and [found here](https://technet.microsoft.com/en-us/library/jj134176(v=ws.11).aspx).
#
# More information on the gpresult command can be [found here](https://technet.microsoft.com/en-us/library/cc733160(v=ws.11).aspx).
#
# More information on how to create a WMI filter can be [found here](https://technet.microsoft.com/en-us/library/cc770562(v=ws.11).aspx).
#
# ### Data Recovery & Backups
#
# **Supplemental Reading for GitLabs Data Recovery**
#
# [GitLabs's response to the **outage** and **data loss** incident](https://about.gitlab.com/2017/02/01/gitlab-dot-com-database-incident/)
#
# **Supplemental Reading for Backup Solutions**
#
# [Microsoft Backup and Restore](https://support.microsoft.com/en-us/help/17127/windows-back-up-restore), [Apple Time Machine](https://support.apple.com/en-us/HT201250)
#
# [Rsync as a backup utility](https://wiki.archlinux.org/index.php/rsync#As_a_backup_utility)
#
# **Supplemental Reading for [RAID Levels](https://en.wikipedia.org/wiki/Standard_RAID_levels)**
