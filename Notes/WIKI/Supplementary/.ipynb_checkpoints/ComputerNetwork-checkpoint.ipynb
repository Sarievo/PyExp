# %% [markdown]
# **Supplementary Reading for The OSI Networking Model**
#
# [ **[OSI_model](https://en.wikipedia.org/wiki/OSI_model) ]** **[whitepapers/standards/osi-model](https://www.sans.org/reading-room/whitepapers/standards/osi-model-overview-543)**
#
# ### The Physical Layer
#
# **Supplemental Reading for Ethernet Over Twisted Pair Technologies**
#
# [Ethernet_over_twisted_pair](https://en.wikipedia.org/wiki/Ethernet_over_twisted_pair)
#
# ### The Data Link Layer
#
# **Supplemental Reading for Broadband Protocols**
#
# [Point-to-Point_Protocol](https://en.wikipedia.org/wiki/Point-to-Point_Protocol) (IETF [rfc1661](https://tools.ietf.org/html/rfc1661))
#
# [Point-to-point_protocol_over_Ethernet](https://en.wikipedia.org/wiki/Point-to-point_protocol_over_Ethernet) (IETF [rfc2516](https://tools.ietf.org/html/rfc2516))
#
# **Supplemental Reading for WAN Protocols**
#
# [Frame_Relay](https://en.wikipedia.org/wiki/Frame_Relay), or [High-Level_Data_Link_Control](https://en.wikipedia.org/wiki/High-Level_Data_Link_Control), or [Asynchronous_Transfer_Mode](https://en.wikipedia.org/wiki/Asynchronous_Transfer_Mode)
#
# ### The Network Layer
#
# **Supplemental Reading for Routing Protocol Examples**
#
# [Routing_Information_Protocol](https://en.wikipedia.org/wiki/Routing_Information_Protocol) (IETF [rfc2453](https://tools.ietf.org/html/rfc2453))
#
# [Enhanced_Interior_Gateway_Routing_Protocol](https://en.wikipedia.org/wiki/Enhanced_Interior_Gateway_Routing_Protocol) (Cisco [16406](https://www.cisco.com/c/en/us/support/docs/ip/enhanced-interior-gateway-routing-protocol-eigrp/16406-eigrp-toc.html))
#
# [Open_Shortest_Path_First](https://en.wikipedia.org/wiki/Open_Shortest_Path_First) (IETF [rfc2328](https://tools.ietf.org/html/rfc2328))
#
# [Border_Gateway_Protocol](https://en.wikipedia.org/wiki/Border_Gateway_Protocol) (IETF [rfc4271](https://tools.ietf.org/html/rfc4271))
#
# **Supplemental Reading for RFCs and Standards**
#
# [ [ietf](https://www.ietf.org/) ] [standards/rfcs/](https://www.ietf.org/standards/rfcs/)
#
# [April_Fools'_Day_Request_for_Comments](https://en.wikipedia.org/wiki/April_Fools%27_Day_Request_for_Comments) : [rfc1149](https://tools.ietf.org/html/rfc1149) and [rfc3514](https://www.ietf.org/rfc/rfc3514.txt)
#
# ### The Transport and Application Layers
#
# **Supplemental Reading for IPv4 Address Exhaustion**
#
# [ [iana](https://www.iana.org/) ] **[AFRINIC](https://afrinic.net/), [ARIN](https://www.arin.net/)**, **[APNIC](https://www.apnic.net/)**, **[LACNIC](https://www.lacnic.net/)**, **[RIPE](https://www.ripe.net/)**
#
# **Supplemental Reading for System Ports versus Ephemeral Ports**
#
# [ [iana](https://www.iana.org/) ] [service-names-port-numbers](https://www.iana.org/assignments/service-names-port-numbers) [List_of_TCP_and_UDP_port_numbers](https://en.wikipedia.org/wiki/List_of_TCP_and_UDP_port_numbers)
#
# **Supplemental Readings for Mobile Device Networks**
#
# Some [Internet_of_things](https://en.wikipedia.org/wiki/Internet_of_things) protocols are [z-wave](https://z-wavealliance.org/about_z-wave_technology/), [zigbee](https://zigbee.org/zigbee-for-developers/zigbee-3-0/), and [Thread](https://www.threadgroup.org/What-is-Thread)
#
# [ [bluetooth](https://www.bluetooth.com/) ] short range wireless network
#
# **Supplemental Reading for Testing Port Connectivity**
#
# [Netcat](https://en.wikipedia.org/wiki/Netcat) (nc) on Linux & macOS, and [Test-NetConnection](https://docs.microsoft.com/powershell/module/nettcpip/test-netconnection) on Windows.
#
# **Supplemental Reading for IPv6 and IPv4 Harmony**
#
# [6in4](https://en.wikipedia.org/wiki/6in4), [Tunnel Setup Protocol](https://en.wikipedia.org/wiki/Tunnel_Setup_Protocol), and [Anything in Anything (AYIYA)](https://en.wikipedia.org/wiki/Anything_In_Anything).
